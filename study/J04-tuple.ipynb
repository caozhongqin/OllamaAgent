# %% [markdown]
# # tuple 是什么？
# > tuple 是 Python 的元组：一种有顺序、不可修改的容器，写法通常用小括号。(PS: 相当Java中数组，但是 tuple 是常量，一旦定义不可更改)
# 强行赋值，则 TypeError: 'tuple' object does not support item assignment

# %%
point = (3, 4)
print(point[0])  # 3
print(point[1])  # 4
point[1] = 5
# Out:
# 3
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 point = (3, 4)
#       2 print(point[0])  # 3
#       3 print(point[1])  # 4
# ----> 4 point[1] = 5
#
# TypeError: 'tuple' object does not support item assignment
